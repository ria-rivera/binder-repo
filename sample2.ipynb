# %% [markdown]
# # Sample 2: Hail Filter

# %%
# Atgenomix-Sample-Hail-Filter
# This demo shows 
# 1. how to use atgenomix-hail to filter variants based on different requirements 
# 2. its corresponding performance.

# %%
from pyspark import SparkContext
from pyspark.sql import SQLContext
from pyspark.sql.functions import struct
from pyspark.sql.types import *
import hail as hl
import datetime
import time

sc = SparkContext.getOrCreate()
sc.setLogLevel("ERROR")
hl.init(sc)

# %%
# Demo Purpose
# Load a Matrix Table generated by annotating (clinvar, dbNSFP, gencode, gnomad) to a whole genome VCF
# This Matrix Table file has 4,941,747 variants.

mt = hl.atgenomix.load_sample_mt()
print(mt.count())
mt.describe()
